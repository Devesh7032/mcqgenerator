# %%
import os
import json
import pandas as pd
import traceback

# %%
from langchain_openai import ChatOpenAI

# %%
import sys
sys.executable
# Out:
# 'c:\\Users\\Devesh\\Downloads\\mcqgenerator\\project\\python.exe'

# %%
key=os.getenv("Open_api_key")

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Devesh\Downloads\mcqgenerator\experiment

# %%
import os
from dotenv import load_dotenv

env_path = r"C:\Users\Devesh\Downloads\mcqgenerator\.env"
load_dotenv(dotenv_path=env_path, override=True)

print("API KEY:", os.getenv("OPENAI_API_KEY"))
# Out:
# API KEY: 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

# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.5
)
